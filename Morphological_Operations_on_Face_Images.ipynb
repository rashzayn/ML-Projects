# %% [markdown]
# <a href="https://colab.research.google.com/github/rashzayn/ML-Projects/blob/main/Morphological_Operations_on_Face_Images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Completed by Rashid Zaynutdinov
# U2110075

import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from google.colab import drive
import cv2

# Mount Google Drive
drive.mount('/content/drive', force_remount=True)

def apply_morphological_operations(image_path):
    # Open the image
    img = Image.open(image_path)

    # Convert image to RGB if it's not already
    img = img.convert('RGB')

    # Convert to grayscale
    gray_image = np.array(img.convert('L'))

    # Create a kernel for morphological operations
    kernel = np.ones((5,5), np.uint8)

    # Perform morphological operations
    opening = cv2.morphologyEx(gray_image, cv2.MORPH_OPEN, kernel)
    closing = cv2.morphologyEx(gray_image, cv2.MORPH_CLOSE, kernel)
    smoothing = cv2.morphologyEx(gray_image, cv2.MORPH_CLOSE, kernel)
    smoothing = cv2.morphologyEx(smoothing, cv2.MORPH_OPEN, kernel)
    gradient = cv2.morphologyEx(gray_image, cv2.MORPH_GRADIENT, kernel)

    # Display results
    fig, axes = plt.subplots(2, 2, figsize=(12, 12))
    ax = axes.ravel()

    ax[0].imshow(opening, cmap='gray')
    ax[0].set_title('Opening')

    ax[1].imshow(closing, cmap='gray')
    ax[1].set_title('Closing')

    ax[2].imshow(smoothing, cmap='gray')
    ax[2].set_title('Morphological Smoothing')

    ax[3].imshow(gradient, cmap='gray')
    ax[3].set_title('Morphological Gradient')

    for a in ax:
        a.axis('off')

    plt.tight_layout()
    plt.show()

# Usage
image_path = '/content/drive/MyDrive/Colab Notebooks/picture 2.jpg'  # Update this path to match your image location
apply_morphological_operations(image_path)
# Out:
# Mounted at /content/drive
