# %% [markdown]
# <a href="https://colab.research.google.com/github/rashzayn/ML-Projects/blob/main/Students_Performance_Mini_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub
path = kagglehub.dataset_download("spscientist/students-performance-in-exams")
# Out:
# Using Colab cache for faster access to the 'students-performance-in-exams' dataset.

# %%
import pandas as pd
import seaborn as sns
import os

# OPTION A: Load a local CSV (Student Marks)
# Place students.csv in the same folder as your notebook/script
df = pd.read_csv(os.path.join(path, "StudentsPerformance.csv"))   # reads a CSV file into a DataFrame

# OPTION B: Load the built-in Iris dataset from Seaborn
# Uncomment the next line to use Iris instead:
# df = sns.load_dataset("iris")

# Peek at the top rows to see column names & values
print(df.head())      # first 5 rows

# Understand structure: rows, columns, data types, missing values
print(df.info())      # non-null counts, dtypes

# Quick stats for numeric columns (mean, std, min, quartiles, max)
print(df.describe())
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# ...
